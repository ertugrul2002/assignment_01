# %% [markdown]
# # Dimensionality Reduction Assignment Demo
#
# This notebook demonstrates the usage of our dimensionality reduction implementation.

# %%
import pandas as pd
import numpy as np
from dimreduce import *

# %% [markdown]
# ## 1. Load the Dataset

# %%
# Replace with your dataset path
df = load_data('knesset_25.xlsx')
print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (12545, 42)
#          city_name  ballot_code  party_avoda  party_shahar_kalkali_hadash  \
# 0  אבו גווייעד שבט          3.1            0                            0
# 1  אבו גווייעד שבט          3.2            1                            0
# 2  אבו גווייעד שבט          3.3            0                            0
# 3  אבו גווייעד שבט          3.4            0                            0
# 4          אבו גוש          1.1            1                            0
#
#    party_bayit_yehudi  party_agudat_israel  party_daled  party_vavmem  \
# 0                   0                    0            4            21
# 1                   0                    0            0             2
# 2                   0                    0            0            12
# 3                   0                    0            0             3
# 4                   0                    0          171            43
#
#    party_shahar_koach_hevrati  party_kama  ...  party_tze'irim_bo'arim  \
# 0                           0           0  ...                       0
# 1                           0           0  ...                       0
# 2                           0           0  ...                       0
# 3                           0           0  ...                       1
# 4                           0           0  ...                       0
#
#    party_manhigut_hevratit  party_kol_hasviva_vehachai  party_halev_hayehudi  \
# 0                        0                           0                     0
# 1                        0                           0                     0
# 2                        0                           0                     0
# 3                        0                           0                     0
# 4                        1                           0                     0
#
#    party_seder_chadash  party_kol  party_beometz_bishvilech  \
# 0                    0          0                         0
# 1                    0          0                         0
# 2                    0          0                         0
# 3                    0          0                         0
# 4                    0          0                         0
#
#    party_kavod_umasoret  party_shas  party_daat_tov_vera
# 0                     0           0                    2
# 1                     0           0                    1
# 2                     0           2                    0
# 3                     0           2                    0
# 4                     0           0                    0
#
# [5 rows x 42 columns]

# %% [markdown]
# ## 2. Group and Aggregate Data

# %%
# Group by city and sum votes
grouped_df = group_and_aggregate_data(df, 'city_name', 'sum')
print("Grouped data shape:", grouped_df.shape)
grouped_df.head()
# Out:
# Grouped data shape: (1216, 40)
#                  party_avoda  party_shahar_kalkali_hadash  party_bayit_yehudi  \
# city_name
# אבו גווייעד שבט            1                            0                   0
# אבו גוש                   14                            1                   1
# אבו סנאן                  34                            0                   3
# אבו עבדון שבט              0                            0                   0
# אבו קורינאת שבט            5                            0                   1
#
#                  party_agudat_israel  party_daled  party_vavmem  \
# city_name
# אבו גווייעד שבט                    0            4            38
# אבו גוש                            3         1263           312
# אבו סנאן                           0          677          2030
# אבו עבדון שבט                      0            1             1
# אבו קורינאת שבט                    0           10            65
#
#                  party_shahar_koach_hevrati  party_kama  \
# city_name
# אבו גווייעד שבט                           0           0
# אבו גוש                                   0           0
# אבו סנאן                                  4           1
# אבו עבדון שבט                             0           0
# אבו קורינאת שבט                           0           0
#
#                  party_koach_lehashpia  party_tzomet  ...  \
# city_name                                             ...
# אבו גווייעד שבט                      1             0  ...
# אבו גוש                              0             0  ...
# אבו סנאן                             2             0  ...
# אבו עבדון שבט                        0             0  ...
# אבו קורינאת שבט                      1             1  ...
#
#                  party_tze'irim_bo'arim  party_manhigut_hevratit  \
# city_name
# אבו גווייעד שבט                       1                        0
# אבו גוש                               2                        7
# אבו סנאן                              1                        4
# אבו עבדון שבט                         0                        0
# אבו קורינאת שבט                       0                        1
#
#                  party_kol_hasviva_vehachai  party_halev_hayehudi  \
# city_name
# אבו גווייעד שבט                           0                     0
# אבו גוש                                   1                     0
# אבו סנאן                                  1                     3
# אבו עבדון שבט                             0                     0
# אבו קורינאת שבט                           0                     0
#
#                  party_seder_chadash  party_kol  party_beometz_bishvilech  \
# city_name
# אבו גווייעד שבט                    0          0                         0
# אבו גוש                            1          1                         3
# אבו סנאן                           1          6                         9
# אבו עבדון שבט                      0          0                         0
# אבו קורינאת שבט                    2          1                         0
#
#                  party_kavod_umasoret  party_shas  party_daat_tov_vera
# city_name
# אבו גווייעד שבט                     0           4                    3
# אבו גוש                             0           4                    0
# אבו סנאן                            0          12                    1
# אבו עבדון שבט                       0           0                    0
# אבו קורינאת שבט                     0           3                    0
#
# [5 rows x 40 columns]

# %% [markdown]
# ## 3. Remove Sparse Columns

# %%
# Remove parties with fewer than 1000 total votes
filtered_df = remove_sparse_columns(grouped_df,1000)
print("filtered data shape:", filtered_df.shape)
filtered_df.head()
# Out:
# filtered data shape: (1216, 26)
#                  party_avoda  party_shahar_kalkali_hadash  party_bayit_yehudi  \
# city_name
# אבו גווייעד שבט            1                            0                   0
# אבו גוש                   14                            1                   1
# אבו סנאן                  34                            0                   3
# אבו עבדון שבט              0                            0                   0
# אבו קורינאת שבט            5                            0                   1
#
#                  party_agudat_israel  party_daled  party_vavmem  party_tet  \
# city_name
# אבו גווייעד שבט                    0            4            38          0
# אבו גוש                            3         1263           312         13
# אבו סנאן                           0          677          2030          6
# אבו עבדון שבט                      0            1             1          0
# אבו קורינאת שבט                    0           10            65          0
#
#                  party_israel_hofshit_demokratit  party_hakalkalit_hahadasha  \
# city_name
# אבו גווייעד שבט                                0                           0
# אבו גוש                                        0                           0
# אבו סנאן                                       4                           0
# אבו עבדון שבט                                  0                           0
# אבו קורינאת שבט                                0                           0
#
#                  party_kahol_lavan  ...  party_raam  party_yesh_atid  \
# city_name                           ...
# אבו גווייעד שבט                  5  ...         468                1
# אבו גוש                          8  ...         838               26
# אבו סנאן                       401  ...        1160              163
# אבו עבדון שבט                    0  ...          39                0
# אבו קורינאת שבט                  0  ...        1096                4
#
#                  party_pesofit  party_tze'irim_bo'arim  \
# city_name
# אבו גווייעד שבט              0                       1
# אבו גוש                      0                       2
# אבו סנאן                     0                       1
# אבו עבדון שבט                0                       0
# אבו קורינאת שבט              1                       0
#
#                  party_kol_hasviva_vehachai  party_seder_chadash  party_kol  \
# city_name
# אבו גווייעד שבט                           0                    0          0
# אבו גוש                                   1                    1          1
# אבו סנאן                                  1                    1          6
# אבו עבדון שבט                             0                    0          0
# אבו קורינאת שבט                           0                    2          1
#
#                  party_beometz_bishvilech  party_shas  party_daat_tov_vera
# city_name
# אבו גווייעד שבט                         0           4                    3
# אבו גוש                                 3           4                    0
# אבו סנאן                                9          12                    1
# אבו עבדון שבט                           0           0                    0
# אבו קורינאת שבט                         0           3                    0
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 4. Dimensionality Reduction

# %%
# Reduce dimensions for cities
reduced_cities = dimensionality_reduction(filtered_df, 2, ['city_name'])
print("Reduced cities data shape:", reduced_cities.shape)
reduced_cities.head()

# %% [markdown]
# ## 5. Visualize Results

# %%
# Create and display interactive plot
fig = create_visualization(reduced_cities, 'cities', ['city_name'])
fig.show()
